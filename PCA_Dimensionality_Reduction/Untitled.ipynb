# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier

# %%
df=pd.read_csv('heart.csv')
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
corr_mat=df.corr()
corr_mat['HeartDisease']
# Out:
# Age                  0.282039
# RestingBP            0.107589
# Cholesterol         -0.232741
# FastingBS            0.267291
# MaxHR               -0.400421
# Oldpeak              0.403951
# HeartDisease         1.000000
# Sex_M                0.305445
# ChestPainType_ATA   -0.401924
# ChestPainType_NAP   -0.212964
# ChestPainType_TA    -0.054790
# RestingECG_Normal   -0.091580
# RestingECG_ST        0.102527
# ExerciseAngina_Y     0.494282
# ST_Slope_Flat        0.554134
# ST_Slope_Up         -0.622164
# Name: HeartDisease, dtype: float64

# %%
df = pd.get_dummies(df, drop_first=True)
df
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40        140          289          0    172      0.0             0
# 1     49        160          180          0    156      1.0             1
# 2     37        130          283          0     98      0.0             0
# 3     48        138          214          0    108      1.5             1
# 4     54        150          195          0    122      0.0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45        110          264          0    132      1.2             1
# 914   68        144          193          1    141      3.4             1
# 915   57        130          131          0    115      1.2             1
# 916   57        130          236          0    174      0.0             1
# 917   38        138          175          0    173      0.0             0
#
#      Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Age                918 non-null    int64
#  1   RestingBP          918 non-null    int64
#  2   Cholesterol        918 non-null    int64
#  3   FastingBS          918 non-null    int64
#  4   MaxHR              918 non-null    int64
#  5   Oldpeak            918 non-null    float64
#  6   HeartDisease       918 non-null    int64
#  7   Sex_M              918 non-null    uint8
#  8   ChestPainType_ATA  918 non-null    uint8
#  9   ChestPainType_NAP  918 non-null    uint8
#  10  ChestPainType_TA   918 non-null    uint8
#  11  RestingECG_Normal  918 non-null    uint8
#  12  RestingECG_ST      918 non-null    uint8
#  13  ExerciseAngina_Y   918 non-null    uint8
#  14  ST_Slope_Flat      918 non-null    uint8
#  15  ST_Slope_Up        918 non-null    uint8
# ...

# %%
scaler=MinMaxScaler()
scaler.fit_transform(df)
# Out:
# array([[0.24489796, 0.7       , 0.47927032, ..., 0.        , 0.        ,
#         1.        ],
#        [0.42857143, 0.8       , 0.29850746, ..., 0.        , 1.        ,
#         0.        ],
#        [0.18367347, 0.65      , 0.46932007, ..., 0.        , 0.        ,
#         1.        ],
#        ...,
#        [0.59183673, 0.65      , 0.2172471 , ..., 1.        , 1.        ,
#         0.        ],
#        [0.59183673, 0.65      , 0.39137645, ..., 0.        , 1.        ,
#         0.        ],
#        [0.20408163, 0.69      , 0.29021559, ..., 0.        , 0.        ,
#         1.        ]])

# %%
scaler
# Out:
# MinMaxScaler()

# %%
inputs=df.drop(['HeartDisease'],axis=1)
inputs
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  Sex_M  \
# 0     40        140          289          0    172      0.0      1
# 1     49        160          180          0    156      1.0      0
# 2     37        130          283          0     98      0.0      1
# 3     48        138          214          0    108      1.5      0
# 4     54        150          195          0    122      0.0      1
# ..   ...        ...          ...        ...    ...      ...    ...
# 913   45        110          264          0    132      1.2      1
# 914   68        144          193          1    141      3.4      1
# 915   57        130          131          0    115      1.2      1
# 916   57        130          236          0    174      0.0      0
# 917   38        138          175          0    173      0.0      1
#
#      ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# 0                    1                  0                 0
# ...

# %%
target=df['HeartDisease']
target
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 913    1
# 914    1
# 915    1
# 916    1
# 917    0
# Name: HeartDisease, Length: 918, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(inputs,target,test_size=0.1,random_state=2)

# %%
model=RandomForestClassifier()
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
model.score(x_test,y_test)
# Out:
# 0.9021739130434783

# %%
pca=PCA(0.95)
pca.fit_transform(df)
# Out:
# array([[ 92.31187081, -29.44811904],
#        [-17.1441299 , -13.73245424],
#        [ 81.90725003,  38.21898194],
#        ...,
#        [-69.00422181,  17.33679153],
#        [ 39.20627186, -33.58743598],
#        [-21.43693888, -37.21981313]])

# %%
x_train_p,x_test_p,y_train_p,y_test_p=train_test_split(inputs,target,test_size=0.1,random_state=2)

# %%
model=RandomForestClassifier()
model.fit(x_train_p,y_train_p)
# Out:
# RandomForestClassifier()

# %%
model.score(x_test_p,y_test_p)
# Out:
# 0.8804347826086957
